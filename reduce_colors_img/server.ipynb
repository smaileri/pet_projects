# %%
from flask import Flask, render_template, request

from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
def reduce_colors(image, n_colors):
    '''
    Arguments:
    image - (n,m,3) ndarray
    n_colors - a number of colors
    '''
    colors = np.reshape(image, (-1,3))
    model = KMeans(n_clusters=n_colors)
    pixels_clustered = model.fit_predict(colors)
    new_colors = {cluster : [np.uint8(color) for color in model.cluster_centers_[cluster]]  for cluster in range(n_colors)}
    new_image = np.array([new_colors[pixel] for pixel in pixels_clustered])
    return np.reshape(new_image, image.shape)

# %%
app = Flask(__name__)

@app.route('/')
def main_page():
    return render_template('send_photo.html')

@app.route('/reduce', methods=['POST'])
def result():
    image, n_colors = request.files["image"], request.form["ncolors"]
    n_colors = int(n_colors)
    image = np.array(Image.open(image))
    plt.imsave('static/img_before.jpg', image)
    new_image = reduce_colors(image, n_colors)
    plt.imsave('static/img_after.jpg', new_image)
    return render_template('show_result.html', number=n_colors)
app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [26/Jul/2023 15:13:40] "GET / HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:13:46] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:13:46] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:13:46] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:13:50] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:13:50] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:13:50] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:15:20] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:20] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:20] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:15:27] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:27] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:27] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:15:34] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:34] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:34] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:15:40] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:40] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:40] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:15:49] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:49] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:49] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:15:58] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:58] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:15:58] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:16:12] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:16:12] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:16:12] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:16:24] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:16:24] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:16:24] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:16:29] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:16:29] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:16:29] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:16:37] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:16:38] "GET /static/img_after.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:16:38] "GET /static/img_before.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:17:03] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:17:03] "GET /static/img_after.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:17:03] "GET /static/img_before.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:17:09] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:17:09] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:17:09] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:17:22] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:17:22] "GET /static/img_after.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:17:22] "GET /static/img_before.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:17:37] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:17:37] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:17:37] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:19:02] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:19:02] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:19:02] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:19:11] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:19:11] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:19:11] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:25:20] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:25:20] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:25:20] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:36:18] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:36:18] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:36:18] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:36:32] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:36:32] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:36:32] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:36:37] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:36:37] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:36:37] "GET /static/img_after.jpg HTTP/1.1" 200 -
# c:\Users\admindc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 127.0.0.1 - - [26/Jul/2023 15:36:41] "POST /reduce HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:36:41] "GET /static/img_before.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jul/2023 15:36:41] "GET /static/img_after.jpg HTTP/1.1" 200 -
